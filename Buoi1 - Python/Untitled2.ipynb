# %%
#câu 1
a = float (input("nhap gia tri a: "))
b = float (input("nhap gia tri b: "))
print("tong: ", a+b)
print("hieu: ",a-b)
print("tich: ",a*b)
if b!=0:
  print("thuong:",a/b)
else: print("khong the chia cho 0")
# Out:
# nhap gia tri a: 3
# nhap gia tri b: 4
# tong:  7.0
# hieu:  -1.0
# tich:  12.0
# thuong: 0.75

# %%
#câu 2
s= "hello word"
kq =s[2:5]
print(kq)
# Out:
# llo

# %%
#câu 3
s= "hello wold"
s= s.strip()
print("chữ hoa: ",s.upper())
print(("chữ thường: ",s.lower))
a= s.replace("H","J")
print("sau khi thay thế: ", a)
# Out:
# chữ hoa:  HELLO WOLD
# ('chữ thường: ', <built-in method lower of str object at 0x7904378a0430>)
# sau khi thay thế:  hello wold

# %%
a = float (input("nhap gia tri a: "))
b = float (input("nhap gia tri b: "))
c = float (input("nhap gia tri c: "))
d = float (input("nhap gia tri d: "))
#câu 4
if a>b:
  print("hello word")
#câu 5
if a==b:
  print("yes")
else: print("no")
#câu 6
if a==b:
 print(1)
elif a>b:
  print(2)
else: print(3)
#câu 7
if a==b and b==d:
  print("hello word")
#câu 8
if a==b and c==d:
  print("hello word!")
#câu 9
print('yes') if a>b else print('no')
# Out:
# nhap gia tri a: 6
# nhap gia tri b: 6
# nhap gia tri c: 5
# nhap gia tri d: 5
# yes
# 1
# hello word!
# no

# %%
#câu 10
a = float (input("nhap gia tri a: "))
b = float (input("nhap gia tri b: "))
print("A") if a>b else print("=") if a==b else print("B")
# Out:
# nhap gia tri a: 5
# nhap gia tri b: 6
# B

# %%
#câu 11
n = int(input("nhập số phần tử: "))
a = [int(input(f"nhâp phần tử thứ {i+1}:  "))
      for i in range(n)]
b = [x for x in a if x % 2==0]
print("mảng chứa số chẳn", b)
# Out:
# nhập số phần tử: 5
# nhâp phần tử thứ 1:  2
# nhâp phần tử thứ 2:  3
# nhâp phần tử thứ 3:  6
# nhâp phần tử thứ 4:  4
# nhâp phần tử thứ 5:  8
# mảng chứa số chẳn [2, 6, 4, 8]

# %%
#câu 12
tong = sum( x for x in range(1000) if x%3==0 or x%5==0)
print("tổng là: ", tong)
# Out:
# tổng là:  233168

# %%
#câu 13
a= [3,9,1,4]
b= [2,7,4,3,2,8]
kq=[]
max_len = max(len(a),len(b))
for i in range (max_len):
  a1 = a[i] if i<len(a) else 0
  b1 = b[i] if i<len(b) else 0
  kq.append(a1+b1)
print(kq)
# Out:
# [5, 16, 5, 7, 2, 8]

# %%
#câu 14
#a
import random
n = int (input("nhap số cột: "))
m = int (input("nhap số dòng: "))
a=[]
for i in range(m):
  dong =[]
  for j in range(n):
    snn = random.randint(1,100)
    dong.append(snn)
  a.append(dong)
print("ma trận vừa tạo là: ")
for dong in a:
  print(dong)
#b
k= int(input("nhập dòng muốn xuất: "))
if 0<= k<=m:
  print(f"các phần tử thuộc dòng {k}: ",a[k-1])
#c
k= int(input("nhập cột muốn xuất: "))
print(f"các phần tử thuộc cột {k}: ", [row[k-1] for row in a])
#d
max_sum=-1
max_row= 0
for i in range(m):
  tong = sum(a[i])
if tong > max_sum:
  max_sum= tong
  max_row= i
print(f"dòng có tổng lớn nhất là {max_row} với tổng là: ", max_sum)
#e
min_tich=
min_col= 0
for j in range(n)
  tich =0
  for i in range(m)
    tich*=a[i][j]
# Out:
# nhap số cột: 3
# nhap số dòng: 3
# ma trận vừa tạo là:
# [33, 21, 92]
# [5, 76, 53]
# [29, 66, 96]
# nhập dòng muốn xuất: 3
# các phần tử thuộc dòng 3:  [29, 66, 96]
# nhập cột muốn xuất: 3
# các phần tử thuộc cột 3:  [92, 53, 96]
# dòng có tổng lớn nhất là 2 với tổng là:  191
